# %%
import pip

def install(package):
  pip.main(['install', package])

try:
  import warnings
  warnings.filterwarnings('ignore')
  import pandas as pd
  from pandas import json_normalize
  import numpy as np
  from plotnine import *
  import statsmodels.api as sm
  import sys
  from sklearn.linear_model import LinearRegression
  from sklearn.linear_model import LogisticRegression 
  from sklearn.preprocessing import StandardScaler 
  from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
  from sklearn.model_selection import train_test_split
  from sklearn.model_selection import KFold
  from sklearn.model_selection import LeaveOneOut
  import seaborn as sns
  import csv
  # %matplotlib inline
  from riotwatcher import LolWatcher, ApiError
except ImportError:
  print('Modules not installed')
  install('riotwatcher')
  install('pandas')
  install('sklearn')
  install('matplotlib')
  install('plotnine')
  install('statsmodels')
  install('seaborn')

def stringToList(string):
  listRes = list(string.split(", "))
  return(listRes)



lol_watcher = LolWatcher('RGAPI-51119e4b-b230-466b-861f-158cf37c5a73')

my_region = 'na1'
modified_region = "americas"

# versions = lol_watcher.data_dragon.versions_for_region(my_region)
# champions_version = versions['n']['champion']
# summoner_spells_version = versions['n']['summoner']
# items_version = versions['n']['item']
# current_champ_list = lol_watcher.data_dragon.champions(champions_version)

def ally1():
  tm1 = input('Enter name of ally 1: ')

  my_puuid = []
  my_id = []
  my_account_id = []
  my_mastery = []

  try:
    tm1Info = lol_watcher.summoner.by_name(my_region, tm1)
    tm1_ranked_stats = lol_watcher.league.by_summoner(my_region, tm1Info['id'])
    print('Analyzing data for', tm1)
  except:
    print(tm1, 'is not a valid summoner name.')
    sys.exit(1)
  
  df_summoner = pd.DataFrame(tm1_ranked_stats, columns = ['leagueId', 'queueType', 'tier', 'rank', 'summonerId', 
    'summonerName', 'leaguePoints', 'wins', 'losses', 'veteran', 'inactive', 'freshBlood', 'hotStreak'])
  try:
    summoner_name = df_summoner.iat[0,5]
    summoner_id = df_summoner.iat[0,4]
    tier = df_summoner.iat[0,2]
    rank = df_summoner.iat[0,3]
    lp = df_summoner.iat[0,6]
    ranked_wins = df_summoner.iat[0,7]
    ranked_losses = df_summoner.iat[0,8]
    total_games = int(ranked_wins) + int(ranked_losses)
    win_loss_ratio = round((int(ranked_wins) / total_games) * 100, 2)
    target = df_summoner.iat[0,4]
  except:
    print('Error in indexing summoner data for', tm1)
    print(tm1, 'may not have enough ranked games played or finished provisionals.')
    sys.exit(2)
  
  try:
    print(summoner_name, 'is currently', tier, rank, lp, 'lp', 'with a win rate of', win_loss_ratio, '%', 'in', total_games, 'ranked games.')
  except:
    pass

  try:
    summoner_encrypted = lol_watcher.summoner.by_id(my_region, target)
    puuid = summoner_encrypted['puuid']
    summonerId = summoner_encrypted['id']
    summoner_account_Id = summoner_encrypted['accountId']
    my_puuid.append(puuid)
    my_id.append(summonerId)
    my_account_id.append(summoner_account_Id)
    my_mastery = lol_watcher.champion_mastery.by_summoner(my_region, my_id[0])
    champ_mastery_df = pd.DataFrame(my_mastery)
    champ_mastery_df.to_csv('ally1_masteries.csv')
  except:
    print('Unable to get champion masteries for', tm1)
    sys.exit(3)
  
  try:
    my_match_ids = []
    me = lol_watcher.summoner.by_name(my_region, tm1)
    my_matches = lol_watcher.match.matchlist_by_puuid(modified_region, my_puuid[0])
    for gameId in my_matches:
      my_match_ids.append(gameId)
  except:
    print('Error in grabbing match IDs for', tm1)
    sys.exit(4)
  
  try:
    m1 = my_match_ids[0]
    m2 = my_match_ids[1]
    m3 = my_match_ids[2]
    m4 = my_match_ids[3]
    m5 = my_match_ids[4]
    m6 = my_match_ids[5]
    m7 = my_match_ids[6]
    m8 = my_match_ids[7]
    m9 = my_match_ids[8]
    m10 = my_match_ids[9]
    m11 = my_match_ids[10]
    m12 = my_match_ids[11]
    m13 = my_match_ids[12]
    m14 = my_match_ids[13]
    m15 = my_match_ids[14]
    m16 = my_match_ids[15]
    m17 = my_match_ids[16]
    m18 = my_match_ids[17]
    m19 = my_match_ids[18]
    m20 = my_match_ids[19]
    m1_history = lol_watcher.match.by_id(modified_region, m1)
    m2_history = lol_watcher.match.by_id(modified_region, m2)
    m3_history = lol_watcher.match.by_id(modified_region, m3)
    m4_history = lol_watcher.match.by_id(modified_region, m4)
    m5_history = lol_watcher.match.by_id(modified_region, m5)
    m6_history = lol_watcher.match.by_id(modified_region, m6)
    m7_history = lol_watcher.match.by_id(modified_region, m7)
    m8_history = lol_watcher.match.by_id(modified_region, m8)
    m9_history = lol_watcher.match.by_id(modified_region, m9)
    m10_history = lol_watcher.match.by_id(modified_region, m10)
    m11_history = lol_watcher.match.by_id(modified_region, m11)
    m12_history = lol_watcher.match.by_id(modified_region, m12)
    m13_history = lol_watcher.match.by_id(modified_region, m13)
    m14_history = lol_watcher.match.by_id(modified_region, m14)
    m15_history = lol_watcher.match.by_id(modified_region, m15)
    m16_history = lol_watcher.match.by_id(modified_region, m16)
    m17_history = lol_watcher.match.by_id(modified_region, m17)
    m18_history = lol_watcher.match.by_id(modified_region, m18)
    m19_history = lol_watcher.match.by_id(modified_region, m19)
    m20_history = lol_watcher.match.by_id(modified_region, m20)
    
    m1_game = []
    m2_game = []
    m3_game = []
    m4_game = []
    m5_game = []
    m6_game = []
    m7_game = []
    m8_game = []
    m9_game = []
    m10_game = []
    m11_game = []
    m12_game = []
    m13_game = []
    m14_game = []
    m15_game = []
    m16_game = []
    m17_game = []
    m18_game = []
    m19_game = []
    m20_game = []

    m1_game.append(m1_history)
    m2_game.append(m2_history)
    m3_game.append(m3_history)
    m4_game.append(m4_history)
    m5_game.append(m5_history)
    m6_game.append(m6_history)
    m7_game.append(m7_history)
    m8_game.append(m8_history)
    m9_game.append(m9_history)
    m10_game.append(m10_history)
    m11_game.append(m11_history)
    m12_game.append(m12_history)
    m13_game.append(m13_history)
    m14_game.append(m14_history)
    m15_game.append(m15_history)
    m16_game.append(m16_history)
    m17_game.append(m17_history)
    m18_game.append(m18_history)
    m19_game.append(m19_history)
    m20_game.append(m20_history)
  except:
    pass

  games_to_analyze = []
  participants = []
  games_to_filter = [m1_game, m2_game, m3_game, m4_game, m5_game, m6_game, m7_game, m8_game, m9_game, m10_game,
   m11_game, m12_game, m13_game, m14_game, m15_game, m16_game, m17_game, m18_game, m19_game, m20_game]
  
  try:
    for x in games_to_filter:
      df = pd.DataFrame(x)
      iteration = df['info']
      indexing_interation = iteration[0]
      final_index = indexing_interation['participants']
      if indexing_interation['queueId'] == 420:
        games_to_analyze.append(x)
        for row in final_index:
          participants_row = {}
          if row['summonerName'] == tm1:
            participants_row['summoner'] = row['summonerName']
            participants_row['champion'] = row['championName']
            participants_row['kills'] = row['kills']
            participants_row['deaths'] = row['deaths']
            participants_row['assists'] = row['assists']
            participants_row['totalDamagetoChampions'] = row['totalDamageDealtToChampions']
            participants_row['position'] = row['teamPosition']
            participants_row['win'] = row['win']
            participants.append(participants_row)
        else:
          pass
    else:
      pass
  except:
    print('Error in parsing match data of', tm1, 'to DataFrame.')
    sys.exit(5)
  
  try:
    tm1df = pd.DataFrame(participants)
    tm1df.to_csv('tm1_data.csv')
    count = open("tm1_data.csv")
    reader = csv.reader(count)
    lines = len(list(reader))
    final_lines = 20 - int(lines)
    if final_lines > 1:
      print('WARNING: ', tm1, 'has', final_lines, 'games out of the past 20 that are not Ranked Solo/Duo. Ignoring in calculations...')
      print('Data extraction successful for', tm1)
    else:
      pass
  except:
    print('Error in creating/reading CSV for the match history of', tm1)


def ally2():
  tm2 = input('Enter name of ally 2: ')

  my_puuid = []
  my_id = []
  my_account_id = []
  my_mastery = []

  try:
    tm2Info = lol_watcher.summoner.by_name(my_region, tm2)
    tm2_ranked_stats = lol_watcher.league.by_summoner(my_region, tm2Info['id'])
    print('Analyzing data for', tm2)
  except:
    print(tm2, 'is not a valid summoner name.')
    sys.exit(1)
  
  df_summoner = pd.DataFrame(tm2_ranked_stats, columns = ['leagueId', 'queueType', 'tier', 'rank', 'summonerId', 
    'summonerName', 'leaguePoints', 'wins', 'losses', 'veteran', 'inactive', 'freshBlood', 'hotStreak'])
  try:
    summoner_name = df_summoner.iat[0,5]
    summoner_id = df_summoner.iat[0,4]
    tier = df_summoner.iat[0,2]
    rank = df_summoner.iat[0,3]
    lp = df_summoner.iat[0,6]
    ranked_wins = df_summoner.iat[0,7]
    ranked_losses = df_summoner.iat[0,8]
    total_games = int(ranked_wins) + int(ranked_losses)
    win_loss_ratio = round((int(ranked_wins) / total_games) * 100, 2)
    target = df_summoner.iat[0,4]
  except:
    print('Error in indexing summoner data for', tm2)
    print(tm2, 'may not have enough ranked games played or finished provisionals.')
    sys.exit(2)
  
  try:
    print(summoner_name, 'is currently', tier, rank, lp, 'lp', 'with a win rate of', win_loss_ratio, '%', 'in', total_games, 'ranked games.')
  except:
    pass

  try:
    summoner_encrypted = lol_watcher.summoner.by_id(my_region, target)
    puuid = summoner_encrypted['puuid']
    summonerId = summoner_encrypted['id']
    summoner_account_Id = summoner_encrypted['accountId']
    my_puuid.append(puuid)
    my_id.append(summonerId)
    my_account_id.append(summoner_account_Id)
    my_mastery = lol_watcher.champion_mastery.by_summoner(my_region, my_id[0])
    champ_mastery_df = pd.DataFrame(my_mastery)
    champ_mastery_df.to_csv('ally2_masteries.csv')
  except:
    print('Unable to get champion masteries for', tm2)
    sys.exit(3)
  
  try:
    my_match_ids = []
    me = lol_watcher.summoner.by_name(my_region, tm2)
    my_matches = lol_watcher.match.matchlist_by_puuid(modified_region, my_puuid[0])
    for gameId in my_matches:
      my_match_ids.append(gameId)
  except:
    print('Error in grabbing match IDs for', tm2)
    sys.exit(4)
  
  try:
    m1 = my_match_ids[0]
    m2 = my_match_ids[1]
    m3 = my_match_ids[2]
    m4 = my_match_ids[3]
    m5 = my_match_ids[4]
    m6 = my_match_ids[5]
    m7 = my_match_ids[6]
    m8 = my_match_ids[7]
    m9 = my_match_ids[8]
    m10 = my_match_ids[9]
    m11 = my_match_ids[10]
    m12 = my_match_ids[11]
    m13 = my_match_ids[12]
    m14 = my_match_ids[13]
    m15 = my_match_ids[14]
    m16 = my_match_ids[15]
    m17 = my_match_ids[16]
    m18 = my_match_ids[17]
    m19 = my_match_ids[18]
    m20 = my_match_ids[19]
    m1_history = lol_watcher.match.by_id(modified_region, m1)
    m2_history = lol_watcher.match.by_id(modified_region, m2)
    m3_history = lol_watcher.match.by_id(modified_region, m3)
    m4_history = lol_watcher.match.by_id(modified_region, m4)
    m5_history = lol_watcher.match.by_id(modified_region, m5)
    m6_history = lol_watcher.match.by_id(modified_region, m6)
    m7_history = lol_watcher.match.by_id(modified_region, m7)
    m8_history = lol_watcher.match.by_id(modified_region, m8)
    m9_history = lol_watcher.match.by_id(modified_region, m9)
    m10_history = lol_watcher.match.by_id(modified_region, m10)
    m11_history = lol_watcher.match.by_id(modified_region, m11)
    m12_history = lol_watcher.match.by_id(modified_region, m12)
    m13_history = lol_watcher.match.by_id(modified_region, m13)
    m14_history = lol_watcher.match.by_id(modified_region, m14)
    m15_history = lol_watcher.match.by_id(modified_region, m15)
    m16_history = lol_watcher.match.by_id(modified_region, m16)
    m17_history = lol_watcher.match.by_id(modified_region, m17)
    m18_history = lol_watcher.match.by_id(modified_region, m18)
    m19_history = lol_watcher.match.by_id(modified_region, m19)
    m20_history = lol_watcher.match.by_id(modified_region, m20)
    
    m1_game = []
    m2_game = []
    m3_game = []
    m4_game = []
    m5_game = []
    m6_game = []
    m7_game = []
    m8_game = []
    m9_game = []
    m10_game = []
    m11_game = []
    m12_game = []
    m13_game = []
    m14_game = []
    m15_game = []
    m16_game = []
    m17_game = []
    m18_game = []
    m19_game = []
    m20_game = []

    m1_game.append(m1_history)
    m2_game.append(m2_history)
    m3_game.append(m3_history)
    m4_game.append(m4_history)
    m5_game.append(m5_history)
    m6_game.append(m6_history)
    m7_game.append(m7_history)
    m8_game.append(m8_history)
    m9_game.append(m9_history)
    m10_game.append(m10_history)
    m11_game.append(m11_history)
    m12_game.append(m12_history)
    m13_game.append(m13_history)
    m14_game.append(m14_history)
    m15_game.append(m15_history)
    m16_game.append(m16_history)
    m17_game.append(m17_history)
    m18_game.append(m18_history)
    m19_game.append(m19_history)
    m20_game.append(m20_history)
  except:
    pass

  games_to_analyze = []
  participants = []
  games_to_filter = [m1_game, m2_game, m3_game, m4_game, m5_game, m6_game, m7_game, m8_game, m9_game, m10_game,
   m11_game, m12_game, m13_game, m14_game, m15_game, m16_game, m17_game, m18_game, m19_game, m20_game]
  
  try:
    for x in games_to_filter:
      df = pd.DataFrame(x)
      iteration = df['info']
      indexing_interation = iteration[0]
      final_index = indexing_interation['participants']
      if indexing_interation['queueId'] == 420:
        games_to_analyze.append(x)
        for row in final_index:
          participants_row = {}
          if row['summonerName'] == tm2:
            participants_row['summoner'] = row['summonerName']
            participants_row['champion'] = row['championName']
            participants_row['kills'] = row['kills']
            participants_row['deaths'] = row['deaths']
            participants_row['assists'] = row['assists']
            participants_row['totalDamagetoChampions'] = row['totalDamageDealtToChampions']
            participants_row['position'] = row['teamPosition']
            participants_row['win'] = row['win']
            participants.append(participants_row)
        else:
          pass
    else:
      pass
  except:
    print('Error in parsing match data of', tm2, 'to DataFrame.')
    sys.exit(5)
  
  try:
    tm1df = pd.DataFrame(participants)
    tm1df.to_csv('tm2_data.csv')
    count = open("tm2_data.csv")
    reader = csv.reader(count)
    lines = len(list(reader))
    final_lines = 20 - int(lines)
    if final_lines > 1:
      print('WARNING: ', tm2, 'has', final_lines, 'games out of the past 20 that are not Ranked Solo/Duo. Ignoring in calculations...')
      print('Data extraction successful for', tm2)
    else:
      pass
  except:
    print('Error in creating/reading CSV for the match history of', tm2)

def ally3():
  tm3 = input('Enter name of ally 3: ')

  my_puuid = []
  my_id = []
  my_account_id = []
  my_mastery = []

  try:
    tm3Info = lol_watcher.summoner.by_name(my_region, tm3)
    tm3_ranked_stats = lol_watcher.league.by_summoner(my_region, tm3Info['id'])
    print('Analyzing data for', tm3)
  except:
    print(tm3, 'is not a valid summoner name.')
    sys.exit(1)
  
  df_summoner = pd.DataFrame(tm3_ranked_stats, columns = ['leagueId', 'queueType', 'tier', 'rank', 'summonerId', 
    'summonerName', 'leaguePoints', 'wins', 'losses', 'veteran', 'inactive', 'freshBlood', 'hotStreak'])
  try:
    summoner_name = df_summoner.iat[0,5]
    summoner_id = df_summoner.iat[0,4]
    tier = df_summoner.iat[0,2]
    rank = df_summoner.iat[0,3]
    lp = df_summoner.iat[0,6]
    ranked_wins = df_summoner.iat[0,7]
    ranked_losses = df_summoner.iat[0,8]
    total_games = int(ranked_wins) + int(ranked_losses)
    win_loss_ratio = round((int(ranked_wins) / total_games) * 100, 2)
    target = df_summoner.iat[0,4]
  except:
    print('Error in indexing summoner data for', tm3)
    print(tm3, 'may not have enough ranked games played or finished provisionals.')
    sys.exit(2)
  
  try:
    print(summoner_name, 'is currently', tier, rank, lp, 'lp', 'with a win rate of', win_loss_ratio, '%', 'in', total_games, 'ranked games.')
  except:
    pass

  try:
    summoner_encrypted = lol_watcher.summoner.by_id(my_region, target)
    puuid = summoner_encrypted['puuid']
    summonerId = summoner_encrypted['id']
    summoner_account_Id = summoner_encrypted['accountId']
    my_puuid.append(puuid)
    my_id.append(summonerId)
    my_account_id.append(summoner_account_Id)
    my_mastery = lol_watcher.champion_mastery.by_summoner(my_region, my_id[0])
    champ_mastery_df = pd.DataFrame(my_mastery)
    champ_mastery_df.to_csv('ally3_masteries.csv')
  except:
    print('Unable to get champion masteries for', tm3)
    sys.exit(3)
  
  try:
    my_match_ids = []
    me = lol_watcher.summoner.by_name(my_region, tm3)
    my_matches = lol_watcher.match.matchlist_by_puuid(modified_region, my_puuid[0])
    for gameId in my_matches:
      my_match_ids.append(gameId)
  except:
    print('Error in grabbing match IDs for', tm3)
    sys.exit(4)
  
  try:
    m1 = my_match_ids[0]
    m2 = my_match_ids[1]
    m3 = my_match_ids[2]
    m4 = my_match_ids[3]
    m5 = my_match_ids[4]
    m6 = my_match_ids[5]
    m7 = my_match_ids[6]
    m8 = my_match_ids[7]
    m9 = my_match_ids[8]
    m10 = my_match_ids[9]
    m11 = my_match_ids[10]
    m12 = my_match_ids[11]
    m13 = my_match_ids[12]
    m14 = my_match_ids[13]
    m15 = my_match_ids[14]
    m16 = my_match_ids[15]
    m17 = my_match_ids[16]
    m18 = my_match_ids[17]
    m19 = my_match_ids[18]
    m20 = my_match_ids[19]
    m1_history = lol_watcher.match.by_id(modified_region, m1)
    m2_history = lol_watcher.match.by_id(modified_region, m2)
    m3_history = lol_watcher.match.by_id(modified_region, m3)
    m4_history = lol_watcher.match.by_id(modified_region, m4)
    m5_history = lol_watcher.match.by_id(modified_region, m5)
    m6_history = lol_watcher.match.by_id(modified_region, m6)
    m7_history = lol_watcher.match.by_id(modified_region, m7)
    m8_history = lol_watcher.match.by_id(modified_region, m8)
    m9_history = lol_watcher.match.by_id(modified_region, m9)
    m10_history = lol_watcher.match.by_id(modified_region, m10)
    m11_history = lol_watcher.match.by_id(modified_region, m11)
    m12_history = lol_watcher.match.by_id(modified_region, m12)
    m13_history = lol_watcher.match.by_id(modified_region, m13)
    m14_history = lol_watcher.match.by_id(modified_region, m14)
    m15_history = lol_watcher.match.by_id(modified_region, m15)
    m16_history = lol_watcher.match.by_id(modified_region, m16)
    m17_history = lol_watcher.match.by_id(modified_region, m17)
    m18_history = lol_watcher.match.by_id(modified_region, m18)
    m19_history = lol_watcher.match.by_id(modified_region, m19)
    m20_history = lol_watcher.match.by_id(modified_region, m20)
    
    m1_game = []
    m2_game = []
    m3_game = []
    m4_game = []
    m5_game = []
    m6_game = []
    m7_game = []
    m8_game = []
    m9_game = []
    m10_game = []
    m11_game = []
    m12_game = []
    m13_game = []
    m14_game = []
    m15_game = []
    m16_game = []
    m17_game = []
    m18_game = []
    m19_game = []
    m20_game = []

    m1_game.append(m1_history)
    m2_game.append(m2_history)
    m3_game.append(m3_history)
    m4_game.append(m4_history)
    m5_game.append(m5_history)
    m6_game.append(m6_history)
    m7_game.append(m7_history)
    m8_game.append(m8_history)
    m9_game.append(m9_history)
    m10_game.append(m10_history)
    m11_game.append(m11_history)
    m12_game.append(m12_history)
    m13_game.append(m13_history)
    m14_game.append(m14_history)
    m15_game.append(m15_history)
    m16_game.append(m16_history)
    m17_game.append(m17_history)
    m18_game.append(m18_history)
    m19_game.append(m19_history)
    m20_game.append(m20_history)
  except:
    pass

  games_to_analyze = []
  participants = []
  games_to_filter = [m1_game, m2_game, m3_game, m4_game, m5_game, m6_game, m7_game, m8_game, m9_game, m10_game,
   m11_game, m12_game, m13_game, m14_game, m15_game, m16_game, m17_game, m18_game, m19_game, m20_game]
  
  try:
    for x in games_to_filter:
      df = pd.DataFrame(x)
      iteration = df['info']
      indexing_interation = iteration[0]
      final_index = indexing_interation['participants']
      if indexing_interation['queueId'] == 420:
        games_to_analyze.append(x)
        for row in final_index:
          participants_row = {}
          if row['summonerName'] == tm3:
            participants_row['summoner'] = row['summonerName']
            participants_row['champion'] = row['championName']
            participants_row['kills'] = row['kills']
            participants_row['deaths'] = row['deaths']
            participants_row['assists'] = row['assists']
            participants_row['totalDamagetoChampions'] = row['totalDamageDealtToChampions']
            participants_row['position'] = row['teamPosition']
            participants_row['win'] = row['win']
            participants.append(participants_row)
        else:
          pass
    else:
      pass
  except:
    print('Error in parsing match data of', tm3, 'to DataFrame.')
    sys.exit(5)
  
  try:
    tm1df = pd.DataFrame(participants)
    tm1df.to_csv('tm3_data.csv')
    count = open("tm3_data.csv")
    reader = csv.reader(count)
    lines = len(list(reader))
    final_lines = 20 - int(lines)
    if final_lines > 1:
      print('WARNING: ', tm3, 'has', final_lines, 'games out of the past 20 that are not Ranked Solo/Duo. Ignoring in calculations...')
      print('Data extraction successful for', tm3)
    else:
      pass
  except:
    print('Error in creating/reading CSV for the match history of', tm3)


def ally4():
  tm4 = input('Enter name of ally 4: ')

  my_puuid = []
  my_id = []
  my_account_id = []
  my_mastery = []

  try:
    tm4Info = lol_watcher.summoner.by_name(my_region, tm4)
    tm4_ranked_stats = lol_watcher.league.by_summoner(my_region, tm4Info['id'])
    print('Analyzing data for', tm4)
  except:
    print(tm4, 'is not a valid summoner name.')
    sys.exit(1)
  
  df_summoner = pd.DataFrame(tm4_ranked_stats, columns = ['leagueId', 'queueType', 'tier', 'rank', 'summonerId', 
    'summonerName', 'leaguePoints', 'wins', 'losses', 'veteran', 'inactive', 'freshBlood', 'hotStreak'])
  try:
    summoner_name = df_summoner.iat[0,5]
    summoner_id = df_summoner.iat[0,4]
    tier = df_summoner.iat[0,2]
    rank = df_summoner.iat[0,3]
    lp = df_summoner.iat[0,6]
    ranked_wins = df_summoner.iat[0,7]
    ranked_losses = df_summoner.iat[0,8]
    total_games = int(ranked_wins) + int(ranked_losses)
    win_loss_ratio = round((int(ranked_wins) / total_games) * 100, 2)
    target = df_summoner.iat[0,4]
  except:
    print('Error in indexing summoner data for', tm4)
    print(tm4, 'may not have enough ranked games played or finished provisionals.')
    sys.exit(2)
  
  try:
    print(summoner_name, 'is currently', tier, rank, lp, 'lp', 'with a win rate of', win_loss_ratio, '%', 'in', total_games, 'ranked games.')
  except:
    pass

  try:
    summoner_encrypted = lol_watcher.summoner.by_id(my_region, target)
    puuid = summoner_encrypted['puuid']
    summonerId = summoner_encrypted['id']
    summoner_account_Id = summoner_encrypted['accountId']
    my_puuid.append(puuid)
    my_id.append(summonerId)
    my_account_id.append(summoner_account_Id)
    my_mastery = lol_watcher.champion_mastery.by_summoner(my_region, my_id[0])
    champ_mastery_df = pd.DataFrame(my_mastery)
    champ_mastery_df.to_csv('ally4_masteries.csv')
  except:
    print('Unable to get champion masteries for', tm4)
    sys.exit(3)
  
  try:
    my_match_ids = []
    me = lol_watcher.summoner.by_name(my_region, tm4)
    my_matches = lol_watcher.match.matchlist_by_puuid(modified_region, my_puuid[0])
    for gameId in my_matches:
      my_match_ids.append(gameId)
  except:
    print('Error in grabbing match IDs for', tm4)
    sys.exit(4)
  
  try:
    m1 = my_match_ids[0]
    m2 = my_match_ids[1]
    m3 = my_match_ids[2]
    m4 = my_match_ids[3]
    m5 = my_match_ids[4]
    m6 = my_match_ids[5]
    m7 = my_match_ids[6]
    m8 = my_match_ids[7]
    m9 = my_match_ids[8]
    m10 = my_match_ids[9]
    m11 = my_match_ids[10]
    m12 = my_match_ids[11]
    m13 = my_match_ids[12]
    m14 = my_match_ids[13]
    m15 = my_match_ids[14]
    m16 = my_match_ids[15]
    m17 = my_match_ids[16]
    m18 = my_match_ids[17]
    m19 = my_match_ids[18]
    m20 = my_match_ids[19]
    m1_history = lol_watcher.match.by_id(modified_region, m1)
    m2_history = lol_watcher.match.by_id(modified_region, m2)
    m3_history = lol_watcher.match.by_id(modified_region, m3)
    m4_history = lol_watcher.match.by_id(modified_region, m4)
    m5_history = lol_watcher.match.by_id(modified_region, m5)
    m6_history = lol_watcher.match.by_id(modified_region, m6)
    m7_history = lol_watcher.match.by_id(modified_region, m7)
    m8_history = lol_watcher.match.by_id(modified_region, m8)
    m9_history = lol_watcher.match.by_id(modified_region, m9)
    m10_history = lol_watcher.match.by_id(modified_region, m10)
    m11_history = lol_watcher.match.by_id(modified_region, m11)
    m12_history = lol_watcher.match.by_id(modified_region, m12)
    m13_history = lol_watcher.match.by_id(modified_region, m13)
    m14_history = lol_watcher.match.by_id(modified_region, m14)
    m15_history = lol_watcher.match.by_id(modified_region, m15)
    m16_history = lol_watcher.match.by_id(modified_region, m16)
    m17_history = lol_watcher.match.by_id(modified_region, m17)
    m18_history = lol_watcher.match.by_id(modified_region, m18)
    m19_history = lol_watcher.match.by_id(modified_region, m19)
    m20_history = lol_watcher.match.by_id(modified_region, m20)
    
    m1_game = []
    m2_game = []
    m3_game = []
    m4_game = []
    m5_game = []
    m6_game = []
    m7_game = []
    m8_game = []
    m9_game = []
    m10_game = []
    m11_game = []
    m12_game = []
    m13_game = []
    m14_game = []
    m15_game = []
    m16_game = []
    m17_game = []
    m18_game = []
    m19_game = []
    m20_game = []

    m1_game.append(m1_history)
    m2_game.append(m2_history)
    m3_game.append(m3_history)
    m4_game.append(m4_history)
    m5_game.append(m5_history)
    m6_game.append(m6_history)
    m7_game.append(m7_history)
    m8_game.append(m8_history)
    m9_game.append(m9_history)
    m10_game.append(m10_history)
    m11_game.append(m11_history)
    m12_game.append(m12_history)
    m13_game.append(m13_history)
    m14_game.append(m14_history)
    m15_game.append(m15_history)
    m16_game.append(m16_history)
    m17_game.append(m17_history)
    m18_game.append(m18_history)
    m19_game.append(m19_history)
    m20_game.append(m20_history)
  except:
    pass

  games_to_analyze = []
  participants = []
  games_to_filter = [m1_game, m2_game, m3_game, m4_game, m5_game, m6_game, m7_game, m8_game, m9_game, m10_game,
   m11_game, m12_game, m13_game, m14_game, m15_game, m16_game, m17_game, m18_game, m19_game, m20_game]
  
  try:
    for x in games_to_filter:
      df = pd.DataFrame(x)
      iteration = df['info']
      indexing_interation = iteration[0]
      final_index = indexing_interation['participants']
      if indexing_interation['queueId'] == 420:
        games_to_analyze.append(x)
        for row in final_index:
          participants_row = {}
          if row['summonerName'] == tm4:
            participants_row['summoner'] = row['summonerName']
            participants_row['champion'] = row['championName']
            participants_row['kills'] = row['kills']
            participants_row['deaths'] = row['deaths']
            participants_row['assists'] = row['assists']
            participants_row['totalDamagetoChampions'] = row['totalDamageDealtToChampions']
            participants_row['position'] = row['teamPosition']
            participants_row['win'] = row['win']
            participants.append(participants_row)
        else:
          pass
    else:
      pass
  except:
    print('Error in parsing match data of', tm4, 'to DataFrame.')
    sys.exit(5)
  
  try:
    tm1df = pd.DataFrame(participants)
    tm1df.to_csv('tm4_data.csv')
    count = open("tm4_data.csv")
    reader = csv.reader(count)
    lines = len(list(reader))
    final_lines = 20 - int(lines)
    if final_lines > 1:
      print('WARNING: ', tm4, 'has', final_lines, 'games out of the past 20 that are not Ranked Solo/Duo. Ignoring in calculations...')
      print('Data extraction successful for', tm4)
    else:
      pass
  except:
    print('Error in creating/reading CSV for the match history of', tm4)

ally1()
ally2()
ally3()
ally4()
# Out:
# Analyzing data for protough
# protough is currently GOLD II 36 lp with a win rate of 51.95 % in 77 ranked games.
# WARNING:  protough has 7 games out of the past 20 that are not Ranked Solo/Duo. Ignoring in calculations...
# Data extraction successful for protough
# Analyzing data for walfu beater
# walfu beater is currently GOLD II 57 lp with a win rate of 52.22 % in 180 ranked games.
# WARNING:  walfu beater has 11 games out of the past 20 that are not Ranked Solo/Duo. Ignoring in calculations...
# Data extraction successful for walfu beater
# Analyzing data for 1stshotkill
# 1stShotKill is currently PLATINUM IV 6 lp with a win rate of 57.35 % in 68 ranked games.
# WARNING:  1stshotkill has 19 games out of the past 20 that are not Ranked Solo/Duo. Ignoring in calculations...
# Data extraction successful for 1stshotkill
#  is not a valid summoner name.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /usr/local/lib/python3.8/site-packages/riotwatcher/Handlers/ThrowOnErrorHandler.py:18, in ThrowOnErrorHandler.after_request(self, region, endpoint_name, method_name, url, response)
#      <a href='file:///usr/local/lib/python3.8/site-packages/riotwatcher/Handlers/ThrowOnErrorHandler.py?line=16'>17</a> try:
# ---> <a href='file:///usr/local/lib/python3.8/site-packages/riotwatcher/Handlers/ThrowOnErrorHandler.py?line=17'>18</a>     response.raise_for_status()
#      <a href='file:///usr/local/lib/python3.8/site-packages/riotwatcher/Handlers/ThrowOnErrorHandler.py?line=18'>19</a> except requests.HTTPError as err:
#
# File /usr/local/lib/python3.8/site-packages/requests/models.py:960, in Response.raise_for_status(self)
#     <a href='file:///usr/local/lib/python3.8/site-packages/requests/models.py?line=958'>959</a> if http_error_msg:
# --> <a href='file:///usr/local/lib/python3.8/site-packages/requests/models.py?line=959'>960</a>     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://na1.api.riotgames.com/lol/summoner/v4/summoners/by-name/
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# /Users/isaacmin/Documents/Chapman University/Junior year/CPSC 392/CPSC392ParlettPelleriti/aa-IsaacMin/Personal Projects/showtime.ipynb Cell 1' in ally4()
#     <a href='vscode-notebook-cell:/Users/isaacmin/Documents/Chapman%20University/Junior%20year/CPSC%20392/CPSC392ParlettPelleriti/aa-IsaacMin/Personal%20Projects/showtime.ipynb#ch0000000?line=656'>657</a> try:
# --> <a href='vscode-notebook-cell:/Users/isaacmin/Documents/Chapman%20University/Junior%20year/CPSC%20392/CPSC392ParlettPelleriti/aa-IsaacMin/Personal%20Projects/showtime.ipynb#ch0000000?line=657'>658</a>   tm4Info = lol_watcher.summoner.by_name(my_region, tm4)
#     <a href='vscode-notebook-cell:/Users/isaacmin/Documents/Chapman%20University/Junior%20year/CPSC%20392/CPSC392ParlettPelleriti/aa-IsaacMin/Personal%20Projects/showtime.ipynb#ch0000000?line=658'>659</a>   tm4_ranked_stats = lol_watcher.league.by_summoner(my_region, tm4Info['id'])
#
# File /usr/local/lib/python3.8/site-packages/riotwatcher/_apis/league_of_legends/SummonerApiV4.py:45, in SummonerApiV4.by_name(self, region, summoner_name)
#      <a href='file:///usr/local/lib/python3.8/site-packages/riotwatcher/_apis/league_of_legends/SummonerApiV4.py?line=36'>37</a> """
#      <a href='file:///usr/local/lib/python3.8/site-packages/riotwatcher/_apis/league_of_legends/SummonerApiV4.py?line=37'>38</a> Get a summoner by summoner name
#      <a href='file:///usr/local/lib/python3.8/site-packages/riotwatcher/_apis/league_of_legends/SummonerApiV4.py?line=38'>39</a>
#    (...)
#      <a href='file:///usr/local/lib/python3.8/site-packages/riotwatcher/_apis/league_of_legends/SummonerApiV4.py?line=42'>43</a> :returns: SummonerDTO: represents a summoner
#      <a href='file:///usr/local/lib/python3.8/site-packages/riotwatcher/_apis/league_of_legends/SummonerApiV4.py?line=43'>44</a> """
# ---> <a href='file:///usr/local/lib/python3.8/site-packages/riotwatcher/_apis/league_of_legends/SummonerApiV4.py?line=44'>45</a> return self._request_endpoint(
#      <a href='file:///usr/local/lib/python3.8/site-packages/riotwatcher/_apis/league_of_legends/SummonerApiV4.py?line=45'>46</a>     self.by_name.__name__,
#      <a href='file:///usr/local/lib/python3.8/site-packages/riotwatcher/_apis/league_of_legends/SummonerApiV4.py?line=46'>47</a>     region,
#      <a href='file:///usr/local/lib/python3.8/site-packages/riotwatcher/_apis/league_of_legends/SummonerApiV4.py?line=47'>48</a>     SummonerApiV4Urls.by_name,
#      <a href='file:///usr/local/lib/python3.8/site-packages/riotwatcher/_apis/league_of_legends/SummonerApiV4.py?line=48'>49</a>     summoner_name=summoner_name,
#      <a href='file:///usr/local/lib/python3.8/site-packages/riotwatcher/_apis/league_of_legends/SummonerApiV4.py?line=49'>50</a> )
#
# File /usr/local/lib/python3.8/site-packages/riotwatcher/_apis/NamedEndpoint.py:35, in NamedEndpoint._request_endpoint(self, method_name, region, endpoint, **kwargs)
#      <a href='file:///usr/local/lib/python3.8/site-packages/riotwatcher/_apis/NamedEndpoint.py?line=33'>34</a> url, query = endpoint(platform=region, **kwargs)
# ---> <a href='file:///usr/local/lib/python3.8/site-packages/riotwatcher/_apis/NamedEndpoint.py?line=34'>35</a> return self._base_api.raw_request(
#      <a href='file:///usr/local/lib/python3.8/site-packages/riotwatcher/_apis/NamedEndpoint.py?line=35'>36</a>     self._endpoint_name, method_name, region, url, query
#      <a href='file:///usr/local/lib/python3.8/site-packages/riotwatcher/_apis/NamedEndpoint.py?line=36'>37</a> )
#
# File /usr/local/lib/python3.8/site-packages/riotwatcher/_apis/BaseApi.py:51, in BaseApi.raw_request(self, endpoint_name, method_name, region, url, query_params)
#      <a href='file:///usr/local/lib/python3.8/site-packages/riotwatcher/_apis/BaseApi.py?line=49'>50</a> for handler in self._request_handlers[early_ret_idx:None:-1]:
# ---> <a href='file:///usr/local/lib/python3.8/site-packages/riotwatcher/_apis/BaseApi.py?line=50'>51</a>     mod = handler.after_request(
#      <a href='file:///usr/local/lib/python3.8/site-packages/riotwatcher/_apis/BaseApi.py?line=51'>52</a>         region, endpoint_name, method_name, url, response
#      <a href='file:///usr/local/lib/python3.8/site-packages/riotwatcher/_apis/BaseApi.py?line=52'>53</a>     )
#      <a href='file:///usr/local/lib/python3.8/site-packages/riotwatcher/_apis/BaseApi.py?line=53'>54</a>     if mod is not None:
#
# File /usr/local/lib/python3.8/site-packages/riotwatcher/Handlers/ThrowOnErrorHandler.py:20, in ThrowOnErrorHandler.after_request(self, region, endpoint_name, method_name, url, response)
#      <a href='file:///usr/local/lib/python3.8/site-packages/riotwatcher/Handlers/ThrowOnErrorHandler.py?line=18'>19</a> except requests.HTTPError as err:
# ---> <a href='file:///usr/local/lib/python3.8/site-packages/riotwatcher/Handlers/ThrowOnErrorHandler.py?line=19'>20</a>     raise ApiError(*err.args, request=err.request, response=err.response)
#
# HTTPError: 403 Client Error: Forbidden for url: https://na1.api.riotgames.com/lol/summoner/v4/summoners/by-name/
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /Users/isaacmin/Documents/Chapman University/Junior year/CPSC 392/CPSC392ParlettPelleriti/aa-IsaacMin/Personal Projects/showtime.ipynb Cell 1' in <cell line: 850>()
#     <a href='vscode-notebook-cell:/Users/isaacmin/Documents/Chapman%20University/Junior%20year/CPSC%20392/CPSC392ParlettPelleriti/aa-IsaacMin/Personal%20Projects/showtime.ipynb#ch0000000?line=848'>849</a> ally3()
# --> <a href='vscode-notebook-cell:/Users/isaacmin/Documents/Chapman%20University/Junior%20year/CPSC%20392/CPSC392ParlettPelleriti/aa-IsaacMin/Personal%20Projects/showtime.ipynb#ch0000000?line=849'>850</a> ally4()
#
# /Users/isaacmin/Documents/Chapman University/Junior year/CPSC 392/CPSC392ParlettPelleriti/aa-IsaacMin/Personal Projects/showtime.ipynb Cell 1' in ally4()
#     <a href='vscode-notebook-cell:/Users/isaacmin/Documents/Chapman%20University/Junior%20year/CPSC%20392/CPSC392ParlettPelleriti/aa-IsaacMin/Personal%20Projects/showtime.ipynb#ch0000000?line=661'>662</a>   print(tm4, 'is not a valid summoner name.')
# --> <a href='vscode-notebook-cell:/Users/isaacmin/Documents/Chapman%20University/Junior%20year/CPSC%20392/CPSC392ParlettPelleriti/aa-IsaacMin/Personal%20Projects/showtime.ipynb#ch0000000?line=662'>663</a>   sys.exit(1)
#     <a href='vscode-notebook-cell:/Users/isaacmin/Documents/Chapman%20University/Junior%20year/CPSC%20392/CPSC392ParlettPelleriti/aa-IsaacMin/Personal%20Projects/showtime.ipynb#ch0000000?line=664'>665</a> df_summoner = pd.DataFrame(tm4_ranked_stats, columns = ['leagueId', 'queueType', 'tier', 'rank', 'summonerId',
#     <a href='vscode-notebook-cell:/Users/isaacmin/Documents/Chapman%20University/Junior%20year/CPSC%20392/CPSC392ParlettPelleriti/aa-IsaacMin/Personal%20Projects/showtime.ipynb#ch0000000?line=665'>666</a>   'summonerName', 'leaguePoints', 'wins', 'losses', 'veteran', 'inactive', 'freshBlood', 'hotStreak'])
#
# SystemExit: 1
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File /usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:1951, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py?line=1947'>1948</a> if exception_only:
#    <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py?line=1948'>1949</a>     stb = ['An exception has occurred, use %tb to see '
#    <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py?line=1949'>1950</a>            'the full traceback.\n']
# -> <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py?line=1950'>1951</a>     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py?line=1951'>1952</a>                                                      value))
#    <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py?line=1952'>1953</a> else:
#    <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py?line=1953'>1954</a>     try:
#    <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py?line=1954'>1955</a>         # Exception classes can customise their traceback - we
#    <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py?line=1955'>1956</a>         # use this in IPython.parallel for exceptions occurring
#    <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py?line=1956'>1957</a>         # in the engines. This should return a list of strings.
#
# File /usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py:578, in ListTB.get_exception_only(self, etype, value)
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=569'>570</a> def get_exception_only(self, etype, value):
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=570'>571</a>     """Only print the exception type and message, without a traceback.
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=571'>572</a>
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=572'>573</a>     Parameters
#    (...)
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=575'>576</a>     value : exception value
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=576'>577</a>     """
# --> <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=577'>578</a>     return ListTB.structured_traceback(self, etype, value)
#
# File /usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py:436, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=432'>433</a>     chained_exc_ids.add(id(exception[1]))
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=433'>434</a>     chained_exceptions_tb_offset = 0
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=434'>435</a>     out_list = (
# --> <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=435'>436</a>         self.structured_traceback(
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=436'>437</a>             etype, evalue, (etb, chained_exc_ids),
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=437'>438</a>             chained_exceptions_tb_offset, context)
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=438'>439</a>         + chained_exception_message
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=439'>440</a>         + out_list)
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=441'>442</a> return out_list
#
# File /usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py:1105, in AutoFormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=1102'>1103</a> else:
#    <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=1103'>1104</a>     self.tb = tb
# -> <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=1104'>1105</a> return FormattedTB.structured_traceback(
#    <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=1105'>1106</a>     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#
# File /usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py:999, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=995'>996</a> mode = self.mode
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=996'>997</a> if mode in self.verbose_modes:
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=997'>998</a>     # Verbose modes need a full traceback
# --> <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=998'>999</a>     return VerboseTB.structured_traceback(
#    <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=999'>1000</a>         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=1000'>1001</a>     )
#    <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=1001'>1002</a> elif mode == 'Minimal':
#    <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=1002'>1003</a>     return ListTB.get_exception_only(self, etype, value)
#
# File /usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py:852, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=849'>850</a> """Return a nice text document describing the traceback."""
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=850'>851</a> assert etb is not None
# --> <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=851'>852</a> formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=852'>853</a>                                                        tb_offset)
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=854'>855</a> colors = self.Colors  # just a shorthand + quicker name lookup
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=855'>856</a> colorsnormal = colors.Normal  # used a lot
#
# File /usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py:786, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=783'>784</a> assert isinstance(tb_offset, int)
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=784'>785</a> head = self.prepare_header(etype, self.long_header)
# --> <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=785'>786</a> records = self.get_records(etb, number_of_lines_of_context, tb_offset)
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=787'>788</a> frames = []
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=788'>789</a> skipped = 0
#
# File /usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py:840, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=833'>834</a> options = stack_data.Options(
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=834'>835</a>     before=before,
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=835'>836</a>     after=after,
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=836'>837</a>     pygments_formatter=formatter,
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=837'>838</a> )
#     <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=838'>839</a> assert etb is not None
# --> <a href='file:///usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py?line=839'>840</a> return list(stack_data.FrameInfo.stack_data(etb, options=options))[tb_offset:]
#
# File /usr/local/lib/python3.8/site-packages/stack_data/core.py:546, in FrameInfo.stack_data(cls, frame_or_tb, options, collapse_repeated_frames)
#     <a href='file:///usr/local/lib/python3.8/site-packages/stack_data/core.py?line=529'>530</a> @classmethod
#     <a href='file:///usr/local/lib/python3.8/site-packages/stack_data/core.py?line=530'>531</a> def stack_data(
#     <a href='file:///usr/local/lib/python3.8/site-packages/stack_data/core.py?line=531'>532</a>         cls,
#    (...)
#     <a href='file:///usr/local/lib/python3.8/site-packages/stack_data/core.py?line=535'>536</a>         collapse_repeated_frames: bool = True
#     <a href='file:///usr/local/lib/python3.8/site-packages/stack_data/core.py?line=536'>537</a> ) -> Iterator[Union['FrameInfo', RepeatedFrames]]:
#     <a href='file:///usr/local/lib/python3.8/site-packages/stack_data/core.py?line=537'>538</a>     """
#     <a href='file:///usr/local/lib/python3.8/site-packages/stack_data/core.py?line=538'>539</a>     An iterator of FrameInfo and RepeatedFrames objects representing
#     <a href='file:///usr/local/lib/python3.8/site-packages/stack_data/core.py?line=539'>540</a>     a full traceback or stack. Similar consecutive frames are collapsed into RepeatedFrames
#    (...)
#     <a href='file:///usr/local/lib/python3.8/site-packages/stack_data/core.py?line=543'>544</a>     and optionally an Options object to configure.
#     <a href='file:///usr/local/lib/python3.8/site-packages/stack_data/core.py?line=544'>545</a>     """
# --> <a href='file:///usr/local/lib/python3.8/site-packages/stack_data/core.py?line=545'>546</a>     stack = list(iter_stack(frame_or_tb))
#     <a href='file:///usr/local/lib/python3.8/site-packages/stack_data/core.py?line=547'>548</a>     # Reverse the stack from a frame so that it's in the same order
#     <a href='file:///usr/local/lib/python3.8/site-packages/stack_data/core.py?line=548'>549</a>     # as the order from a traceback, which is the order of a printed
#     <a href='file:///usr/local/lib/python3.8/site-packages/stack_data/core.py?line=549'>550</a>     # traceback when read top to bottom (most recent call last)
#     <a href='file:///usr/local/lib/python3.8/site-packages/stack_data/core.py?line=550'>551</a>     if is_frame(frame_or_tb):
#
# File /usr/local/lib/python3.8/site-packages/stack_data/utils.py:98, in iter_stack(frame_or_tb)
#      <a href='file:///usr/local/lib/python3.8/site-packages/stack_data/utils.py?line=95'>96</a> while frame_or_tb:
#      <a href='file:///usr/local/lib/python3.8/site-packages/stack_data/utils.py?line=96'>97</a>     yield frame_or_tb
# ---> <a href='file:///usr/local/lib/python3.8/site-packages/stack_data/utils.py?line=97'>98</a>     if is_frame(frame_or_tb):
#      <a href='file:///usr/local/lib/python3.8/site-packages/stack_data/utils.py?line=98'>99</a>         frame_or_tb = frame_or_tb.f_back
#     <a href='file:///usr/local/lib/python3.8/site-packages/stack_data/utils.py?line=99'>100</a>     else:
#
# File /usr/local/lib/python3.8/site-packages/stack_data/utils.py:91, in is_frame(frame_or_tb)
#      <a href='file:///usr/local/lib/python3.8/site-packages/stack_data/utils.py?line=89'>90</a> def is_frame(frame_or_tb: Union[FrameType, TracebackType]) -> bool:
# ---> <a href='file:///usr/local/lib/python3.8/site-packages/stack_data/utils.py?line=90'>91</a>     assert_(isinstance(frame_or_tb, (types.FrameType, types.TracebackType)))
#      <a href='file:///usr/local/lib/python3.8/site-packages/stack_data/utils.py?line=91'>92</a>     return isinstance(frame_or_tb, (types.FrameType,))
#
# File /usr/local/lib/python3.8/site-packages/stack_data/utils.py:172, in assert_(condition, error)
#     <a href='file:///usr/local/lib/python3.8/site-packages/stack_data/utils.py?line=169'>170</a> if isinstance(error, str):
#     <a href='file:///usr/local/lib/python3.8/site-packages/stack_data/utils.py?line=170'>171</a>     error = AssertionError(error)
# --> <a href='file:///usr/local/lib/python3.8/site-packages/stack_data/utils.py?line=171'>172</a> raise error
#
# AssertionError:
