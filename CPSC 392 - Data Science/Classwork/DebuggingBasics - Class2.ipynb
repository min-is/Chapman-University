# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Examples

# %%
def squareMyNumber(n):
    square = n*n
    return square
    

k = squareMyNumber(6)

# If I have 6 friends, and we all bring enough treats for everyone, we'll have k treats!
# If each treat costs $1.50, how much did we spend?

spent = k * 1.5

# %%
mySentenceIsTheBestSentence = "You know, like a liar."

for letter in mySentenceIsTheBestSentence:
    if letter == "l":
        print("It's an l!!!")
# Out:
# It's an l!!!
# It's an l!!!

# %%
my_data_frame = "https://raw.githubusercontent.com/cmparlettpelleriti/CPSC392ParlettPelleriti/master/Data/BreastCancer.csv"

d = pd.read_csv(my_data_frame)

d.head()

# hint, look at line 1, and think about ALL the steps you need to do to open a url from github in pandas
# Out:
#          id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0    842302         M  ...                  0.11890          NaN
# 1    842517         M  ...                  0.08902          NaN
# 2  84300903         M  ...                  0.08758          NaN
# 3  84348301         M  ...                  0.17300          NaN
# 4  84358402         M  ...                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
names = ["Chelsea", "Dan", "Craig", "Tony", "Blake", "Cynthia", "Julie"]

for name in names:
    print(name + " gets an A+!!!")
# Out:
# Chelsea gets an A+!!!
# Dan gets an A+!!!
# Craig gets an A+!!!
# Tony gets an A+!!!
# Blake gets an A+!!!
# Cynthia gets an A+!!!
# Julie gets an A+!!!

# %%
mySentence = "Can a bee be said to be or not to be an entire bee if half the bee is not a bee due to an ancient injury?"

words = mySentence
